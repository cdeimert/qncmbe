# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
from numpy import cos, pi

from qncmbe.plotting import styles

styles.use('qncmbe')
styles.use('paper-aip')
# Out:
# INFO (qncmbe.plotting.styles): Installing style "qncmbe"
# INFO (qncmbe.plotting.styles): Wrote to style file "C:\Users\Chris\.matplotlib\stylelib\qncmbe.mplstyle"
# INFO (qncmbe.plotting.styles): Installing style "paper-aip"
# INFO (qncmbe.plotting.styles): Wrote to style file "C:\Users\Chris\.matplotlib\stylelib\paper-aip.mplstyle"

# %%
x = np.linspace(0, 2*pi, 1000)

N = 8

fig, ax = plt.subplots()
for n in range(N):
    y = cos(x - 2*pi*n/N)
    ax.plot(x, y)
# Out:
# <img src="data:image/png;base64,..." width="336.6">
